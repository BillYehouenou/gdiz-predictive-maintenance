# %% [markdown]
# # Analyse exploratoire des données

# %%
import sys
import os
os.chdir("..")

# %%
# pip install mlflow
# pip install --upgrade typing-extensions
# pip install --force-reinstall pydantic mlflow

# %%
from src.dataloader import DataLoader
from src.preprocessor import Preprocessor
from src.train import ModelPipeline
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# ## Chargement des données

# %%
dl = DataLoader()
df = dl.load_raw_data()
# Out:
# 2026-06-14 20:01:57,191 - INFO - Tentative de chargement des données
# 2026-06-14 20:01:57,427 - INFO - Chargement réussi : 1051200 lignes et 18 colonnes.

# %%
df.head(5)
# Out:
#       machine_id machine_type           timestamp  rotational_speed  \
# 0  GDIZ_TEX_M_01            L 2024-01-01 00:00:00          0.000000
# 1  GDIZ_TEX_M_01            L 2024-01-01 00:30:00        678.581139
# 2  GDIZ_TEX_M_01            L 2024-01-01 01:00:00        839.572324
# 3  GDIZ_TEX_M_01            L 2024-01-01 01:30:00        750.222499
# 4  GDIZ_TEX_M_01            L 2024-01-01 02:00:00        796.840877
#
#       torque  tool_wear  process_temperature  vibration  target  \
# 0   0.000000  64.657520            35.313686   0.000000       0
# 1  22.307622  64.668213            42.104284   2.262805       0
# 2  30.229398  64.680691            48.608053   1.941758       0
# 3  21.168159  64.692222            47.525302   2.156718       0
# 4  28.082118  64.703596            50.093868   2.250501       0
#
#    activity_level  benin_season  ambient_temperature  rain_flag   humidity  \
# 0        0.551389             1            30.313686          0  85.516451
# 1        0.470824             1                  NaN          0  89.364166
# 2        0.612091             1            28.767661          0  90.039985
# 3        0.489420             1            28.229405          0  88.948008
# 4        0.538957             1            28.680711          0  91.650012
#
#    dust_concentration  voltage_level  voltage_stability  power_loss_indicator
# 0          100.723377     221.704581          63.536225                     0
# 1           87.228935     224.069424          73.359393                     0
# 2          124.441171     222.410275          66.980111                     0
# 3          111.133921     226.134707          78.554611                     0
# 4          101.026343     223.919258          70.179254                     0

# %% [markdown]
# ## Transformation des données

# %%
# Initialisation du préprocesseur dynamique
preprocessor = Preprocessor()
# Out:
# 2026-06-14 20:02:32,646 - INFO - Features numériques identifiées : ['ambient_temperature', 'process_temperature', 'rotational_speed', 'torque', 'tool_wear', 'activity_level', 'vibration', 'humidity', 'dust_concentration', 'rain_flag', 'power_loss_indicator', 'voltage_level', 'voltage_stability']
# 2026-06-14 20:02:32,647 - INFO - Features catégorielles identifiées : ['benin_season', 'machine_type']

# %%
X = df.drop(columns=[dl.config['dataset']['target_column']], errors='ignore')
X_transformed = preprocessor.fit_transform(X)
# Out:
# 2026-06-14 20:02:42,767 - INFO - Fitting du pipeline de preprocessing en cours...
# 2026-06-14 20:02:44,817 - INFO - Pipeline de preprocessing configuré avec succès.
# 2026-06-14 20:02:44,818 - INFO - Transformation des données en cours...
# 2026-06-14 20:02:45,228 - INFO - Transformation des données terminée.

# %%
print(X.shape, X_transformed.shape)
# Out:
# (1051200, 17) (1051200, 18)

# %% [markdown]
# ## Modélisation

# %%
model = RandomForestClassifier(n_estimators=100)

# %%
trainer = ModelPipeline()
trainer.run_training(
    model=model, 
    train_df=df,
    model_name="RF_Baseline", 
    hyperparameters={"n_estimators": 100}
)
# Out:
# 2026/06/14 20:03:29 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2026/06/14 20:03:29 INFO mlflow.store.db.utils: Updating database tables
# 2026-06-14 20:03:29,779 - INFO - Début du pipeline d'entraînement...
# 2026-06-14 20:03:30,228 - INFO - Données splittées. Train: 840960 lignes, Test: 210240 lignes.
# 2026-06-14 20:03:30,230 - INFO - Features numériques identifiées : ['ambient_temperature', 'process_temperature', 'rotational_speed', 'torque', 'tool_wear', 'activity_level', 'vibration', 'humidity', 'dust_concentration', 'rain_flag', 'power_loss_indicator', 'voltage_level', 'voltage_stability']
# 2026-06-14 20:03:30,230 - INFO - Features catégorielles identifiées : ['benin_season', 'machine_type']
# 2026-06-14 20:03:30,231 - INFO - Entraînement du modèle...
# 2026-06-14 20:03:30,231 - INFO - Fitting du pipeline de preprocessing en cours...
# 2026-06-14 20:03:31,977 - INFO - Pipeline de preprocessing configuré avec succès.
# 2026-06-14 20:03:31,978 - INFO - Transformation des données en cours...
# 2026-06-14 20:03:32,324 - INFO - Transformation des données terminée.
# 2026-06-14 20:05:48,412 - INFO - Entraînement terminé avec succès !
# 2026-06-14 20:05:48,414 - INFO - Transformation des données en cours...
# 2026-06-14 20:05:48,521 - INFO - Transformation des données terminée.
# /Users/billyehouenou/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# 2026-06-14 20:05:49,409 - INFO - Enregistrement des données dans MLflow...
# 2026/06/14 20:05:49 INFO mlflow.utils.uv_utils: Detected uv project: found uv.lock and pyproject.toml in /Users/billyehouenou/Library/CloudStorage/OneDrive-Personnel/mlops-predictive-maintenance
# 2026/06/14 20:05:49 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# 2026/06/14 20:05:49 INFO mlflow.utils.uv_utils: Detected uv project: found uv.lock and pyproject.toml in /Users/billyehouenou/Library/CloudStorage/OneDrive-Personnel/mlops-predictive-maintenance
# 2026/06/14 20:05:49 INFO mlflow.utils.environment: Detected uv project at /Users/billyehouenou/Library/CloudStorage/OneDrive-Personnel/mlops-predictive-maintenance. Attempting to export requirements via 'uv export'.
# 2026/06/14 20:05:49 INFO mlflow.utils.uv_utils: Exported 93 dependencies via uv
# 2026/06/14 20:05:49 INFO mlflow.utils.environment: Successfully exported 93 requirements from uv project. Skipping package capture based inference.
# 2026/06/14 20:05:51 WARNING mlflow.utils.requirements_utils: Detected one or more mismatches between the model's dependencies and the current Python environment:
#  - duckdb (current: 1.5.1, required: duckdb==1.5.3)
#  - gitpython (current: 3.1.50, required: gitpython==3.1.49)
#  - mlflow-skinny (current: 3.12.0, required: mlflow-skinny==3.11.1)
#  - mlflow-tracing (current: 3.12.0, required: mlflow-tracing==3.11.1)
#  - mlflow (current: 3.12.0, required: mlflow==3.11.1)
#  - starlette (current: 0.52.1, required: starlette==1.0.0)
# To fix the mismatches, call `mlflow.pyfunc.get_model_dependencies(model_uri)` to fetch the model's environment and install dependencies using the resulting environment file.
# Registered model 'RF_Baseline' already exists. Creating a new version of this model...
# Created version '2' of model 'RF_Baseline'.
# 2026-06-14 20:05:51,427 - INFO - Pipeline complet sauvegardé localement dans : models/model_pipeline.pkl
# Accuracy: 0.9998
# Precision: 0.0000
# Recall: 0.0000
# F1_score: 0.0000
